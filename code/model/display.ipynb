# %%
import pandas as pd

# %%
restaurants = pd.read_csv("restaurants.csv")
restaurants.drop('vegan_rating', axis=1, inplace=True)
restaurants.drop('gf_rating', axis=1, inplace=True)
restaurants.drop('veg_rating', axis=1, inplace=True)
restaurants.drop('Unnamed: 0', axis=1, inplace=True)
restaurants.drop('Unnamed: 0.1', axis=1, inplace=True)
restaurants.drop('Unnamed: 0.2', axis=1, inplace=True)
restaurants.drop('Unnamed: 0.3', axis=1, inplace=True)
restaurants.drop('Unnamed: 0.4', axis=1, inplace=True)
restaurants
# Out:
#                         place_id                                    name  \
# 0    ChIJMXCBVyZ544kRTZdKnImoaO4  El Jefe's Taqueria - Boston University
# 1    ChIJqXVhCcV544kRW9_Owqj0_Hg                 Carlo's Cucina Italiana
# 2    ChIJaa-5vht644kRzT6aPy9UYOs                     Woody's Grill & Tap
# 3    ChIJUQfERfR544kRPexdI3z6tyU                          Sweet Cheeks Q
# 4    ChIJ1SGgo_V544kRmGe2qAAC1x0                       El Pelón Taqueria
# ..                           ...                                     ...
# 285  ChIJgZ6pgG1644kRLYzhg8GwJbE                      Barcelona Wine Bar
# 286  ChIJ28zCvCh744kRDiXNE2oj8fE        Moxies Boston Seaport Restaurant
# 287  ChIJy1amaCt644kRbKJDKJlDLtk                   Fort Hill Bar & Grill
# 288  ChIJRzsVPRB644kRpWzEweKp4tk                     Earls Kitchen + Bar
# 289  ChIJ99FgsIJw44kRvpdK7YQoiC0                   Avenue One Restaurant
#
#      price_level  rating                                              types  \
# ...

# %%
restaurants[['place_id', 'name', 'rating', 'vegan_ratings', 'gf_ratings', 'veg_ratings']]
# Out:
#                         place_id                                    name  \
# 0    ChIJMXCBVyZ544kRTZdKnImoaO4  El Jefe's Taqueria - Boston University
# 1    ChIJqXVhCcV544kRW9_Owqj0_Hg                 Carlo's Cucina Italiana
# 2    ChIJaa-5vht644kRzT6aPy9UYOs                     Woody's Grill & Tap
# 3    ChIJUQfERfR544kRPexdI3z6tyU                          Sweet Cheeks Q
# 4    ChIJ1SGgo_V544kRmGe2qAAC1x0                       El Pelón Taqueria
# ..                           ...                                     ...
# 285  ChIJgZ6pgG1644kRLYzhg8GwJbE                      Barcelona Wine Bar
# 286  ChIJ28zCvCh744kRDiXNE2oj8fE        Moxies Boston Seaport Restaurant
# 287  ChIJy1amaCt644kRbKJDKJlDLtk                   Fort Hill Bar & Grill
# 288  ChIJRzsVPRB644kRpWzEweKp4tk                     Earls Kitchen + Bar
# 289  ChIJ99FgsIJw44kRvpdK7YQoiC0                   Avenue One Restaurant
#
#      rating  vegan_ratings  gf_ratings  veg_ratings
# ...

# %%
reviews = pd.read_csv("reviews.csv")

# %%
reviews[['place_name', 'rating', 'review_text']]
# Out:
#                                     place_name  rating  \
# 0       El Jefe's Taqueria - Boston University       5
# 1       El Jefe's Taqueria - Boston University       5
# 2       El Jefe's Taqueria - Boston University       3
# 3       El Jefe's Taqueria - Boston University       5
# 4       El Jefe's Taqueria - Boston University       5
# ...                                        ...     ...
# 243484                   Avenue One Restaurant       2
# 243485                   Avenue One Restaurant       5
# 243486                   Avenue One Restaurant       5
# 243487                   Avenue One Restaurant       3
# 243488                   Avenue One Restaurant       5
#
#                                               review_text
# 0       Excellent service and food\nFood: 5/5 | Servic...
# 1                                                     NaN
# 2                                               Food: 3/5
# 3       Valid\nFood: 5/5 | Service: 5/5 | Atmosphere: 5/5
# ...
